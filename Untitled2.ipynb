# %%
import pandas as pd
import folium
import requests
import numpy as np

batting = pd.read_csv('Batting.csv')
player_info_df = pd.read_csv('People.csv')
batting_career = []
listofplayers = []
players_already_entered = []
appearances = pd.read_csv("Appearances.csv")
player_id = player_info_df['playerID']

# %%
def player_search(position):
    desired_players = []
    position = position.lower()
    position_key = "G_" + position
    for player in apperances_career.to_records():
        player_position = max_position(player)
        if position_key == player_position:
            name = player['playerID']
            desired_players.append(name)
    return desired_players

# %%
def max_position(player):
    max_position = -1
    if int(player['G_p']) > max_position:
        max_position = int(player['G_p'])
        position = "G_p"
    if int(player['G_c']) > max_position:
        max_position = int(player['G_c'])
        position = "G_c"
    if int(player['G_1b']) > max_position:
        max_position = int(player['G_1b'])
        position = "G_1b"
    if int(player['G_2b']) > max_position:
        max_position = int(player['G_2b'])
        position = "G_2b"
    if int(player['G_ss']) > max_position:
        max_position = int(player['G_ss'])
        position = "G_ss"
    if int(player['G_3b']) > max_position:
        max_position = int(player['G_3b'])
        position = "G_3b"
    if int(player['G_lf']) > max_position:
        max_position = int(player['G_lf'])
        position = "G_lf"
    if int(player['G_cf']) > max_position:
        max_position = int(player['G_cf'])
        position = "G_cf"
    if int(player['G_rf']) > max_position:
        max_position = int(player['G_rf'])
        position = "G_rf"
    return position

# %%
def career_apperances():
    for player_season in appearances.to_records():
        if player_season['playerID'] in players_already_entered:
            for player in batting_career:
                if player_season['playerID'] == player['playerID']:
                    player['G_p'] += player_season['G_p']
                    player['G_c'] += player_season['G_c']
                    player['G_1b'] += player_season['G_1b']
                    player['G_2b'] += player_season['G_2b']
                    player['G_3b'] += player_season['G_3b']
                    player['G_ss'] += player_season['G_ss']
                    player['G_rf'] += player_season['G_rf']
                    player['G_cf'] += player_season['G_cf']
                    player['G_lf'] += player_season['G_lf']
                    break
        else:
                batting_career_stats = {"playerID" : player_season['playerID'], 'G_cf' : player_season['G_cf'], 'G_p' : player_season['G_p'], 'G_c' : player_season['G_c'], 'G_1b' : player_season['G_1b'] , 'G_2b' : player_season['G_2b'], 'G_3b' : player_season['G_3b'] , 'G_ss' : player_season['G_ss'],  'G_rf' : player_season['G_rf'],  'G_lf' : player_season['G_lf']}
                batting_career.append(batting_career_stats)
                players_already_entered.append(player_season['playerID'])
    return batting_career

# %%
apperances_career = career_apperances()

# %%
apperances_career = pd.DataFrame(apperances_career)

# %%
apperances_career
# Out:
#        G_1b  G_2b  G_3b  G_c  G_cf  G_lf  G_p  G_rf  G_ss   playerID
# 0         0     0     0    0     0     0   55     0     0  acostjo01
# 1         0     0     0    0     0     0  174     0     0  adamsba01
# 2         2     0     0  324     0     0    0     0     0  ainsmed01
# 3         0     0     0    0     0     0  334     0     0  alexape01
# 4         0     0     0   35     0     0    0     0     0  allenni01
# 5         0     0     0    0     0     0   14     0     0  altener01
# 6         0     7    90    0     0     0    0     0    14  austiji01
# 7         0     0     0    0     0     0   48     0     0  ayersdo01
# 8         0     0     0    0     0     0  134     0     0  bagbyji01
# 9         5     0     0    0    95    34    0    41     0  bailege01
# 10        0     0     0    0     0     0   31     0     0  bailesw01
# 11        0     0     6    0     0     0    0     0     0  bairddo01
# 12        0     9     3    0     0     0    0     0  1246  bancrda01
# 13       14    65    45    0     0     0    0     0   155  barbawa01
# 14       86     1     0    0    41   125    0    34     0  barbetu01
# 15        0     0     0    0     0     0  283     0     0  barneje01
# 16        0     0     0    0     0     0  204     0     0  barnevi01
# 17        0     0   160    0     0   335    0   213     0  barnhcl01
# 18        0     0     0    0     0     0    9     0     0  baumgha01
# 19        0     0     0    0     0     0  197     0     0  baynebi01
# 20        0     0     0    0     0     0  149     0     0  bentoru01
# 21        0     0     0    0     0     0  307     0     0  bettshu01
# 22        0     0     0    0     0     0   28     0     0  biemiha01
# 23        0     0     0    0    27   653    0    10     0  bigbeca01
# 24        0     0     0    0     0    12   17     1     0  bigbely01
# 25        0     0     0   60     0     0    0     0     0  billijo01
# 26        0     0     0    0     0     0  304     0     0  blakesh01
# 27        0     0     0    0   150     4    0     0     0  bodiepi01
# 28        0     1   557    0     0     0    0     0     4  boeckto01
# 29        0     0     0    0     0     0   24     0     0  boehlge01
# ...     ...   ...   ...  ...   ...   ...  ...   ...   ...        ...
# 15040     0     0     0    3     0     0    0     0     0  trevijo01
# 15041     0     0     0    0     0     0   69     0     0  trivilo01
# 15042     0     0     0    0     1    20    0     3     0  tuckeky01
# 15043     0     0     0    0     0     0    4     0     0  turnbsp01
# 15044     0     0     0    0     0     0    1     0     0  underdu01
# 15045     0    12     0    0     0     0    0     0     0  uriaslu01
# 15046     0     0     0    0     0     0    8     0     0  valdefr01
# 15047     0     9    11    0     0     3    1     2     4  valenje01
# 15048     0     0     0    0     0     0    9     0     0  vasquan02
# 15049     0     0     0    0     0     0    6     0     0  vastoje01
# 15050     0     2     4    0     2     1    0     1     2  velazan01
# 15051     0     4     0    0     0     0    0     0     2  vielmen01
# 15052     0     0     0   10     0     0    0     0     0  vilorme01
# 15053     0     0     0    0     0     0    4     0     0   vothau01
# 15054     0     0     0    0     0     0    8     0     0  waldema01
# 15055     0     0     7    0     0     0    0     0     0  waldimi01
# 15056     0     0    40    0     0     0    0     0     0   wardta01
# 15057     0     0     0    0     0     0    1     0     0  weissza01
# 15058     0     0     0    0     0     0   10     0     0   wickro01
# 15059     0     0     0    0     0     0    5     0     0  wieckbr01
# 15060     0     9     6    0     0     0    0     0     1  wilkest01
# 15061     0     0     0    0     0     0   10     0     0  williau01
# 15062     0     0     0    0     0     0    0     1     0  williju02
# 15063     0     0     0    0     0     0    3     0     0  wilsobr02
# 15064     0     0     0    0     0     0   22     0     0  wingetr01
# 15065     4     0    13    0     0     0    0     0     0  wisdopa01
# 15066     0     0     0    0     0     0    4     0     0  wrighky01
# 15067     0     0     0   41     0     0    0     0     0  wynnsau01
# 15068     0     0     0    0     0     0   38     0     0  yarbrry01
# 15069     0     0     0    0     0     0   16     0     0  zamorda01
#
# [15070 rows x 10 columns]

# %%
player_search('ss')
# Out:
# ['bancrda01',
#  'barbawa01',
#  'bushdo01',
#  'catonho01',
#  'chapmra01',
#  'clairda01',
#  'cranesa02',
#  'fletcar01',
#  'fordho01',
#  'frencra01',
#  'galloch01',
#  'gerbewa01',
#  'holloch01',
#  'kopfla01',
#  'lamotbo01',
#  'lavando01',
#  'leathha01',
#  'leedu01',
#  'lefeval01',
#  'lunteha01',
#  'maranra01',
#  'mcbrige01',
#  'mccabbi01',
#  'mccanem01',
#  'mccleha01',
#  'olsoniv01',
#  'oneilji01',
#  'peckiro01',
#  'risbesw01',
#  'scottev01',
#  'seweljo01',
#  'shannre01',
#  'sheehja01',
#  'sherire01',
#  'shovljo01',
#  'wardch01',
#  'callafr01',
#  'ellioca01',
#  'ewingre01',
#  'fulghdo01',
#  'johnser01',
#  'kimmiwa01',
#  'merrihe01',
#  'mitchjo01',
#  'pittipi01',
#  'raderdo01',
#  'schreha01',
#  'tavenja01',
#  'toporsp01',
#  'cavenik01',
#  'gagnoch01',
#  'gallagi01',
#  'jackstr01',
#  'maynach01',
#  'rigneto01',
#  'sorrech01',
#  'fowlebo01',
#  'metzle01',
#  'sandhe01',
#  'turgepe01',
#  'wooddo01',
#  'chapmjo01',
#  'cooneji02',
#  'dashiwa01',
#  'davisik01',
#  'devivbe01',
#  'geygach01',
#  'jonesbi03',
#  'nalewfr01',
#  'theveto01',
#  'wrighgl01',
#  'connobu01',
#  'corgach01',
#  'durocle01',
#  'englech01',
#  'farredo01',
#  'grosstu01',
#  'hustaca01',
#  'kanejo02',
#  'koenima01',
#  'mcaulik01',
#  'rogelbi01',
#  'smithre04',
#  'wannipe01',
#  'welchhe01',
#  'buskejo01',
#  'butlejo02',
#  'cronijo01',
#  'emmerfr01',
#  'hunnebi01',
#  'rhyneha01',
#  'stutzge01',
#  'baldwhe01',
#  'bartedi01',
#  'boleyjo01',
#  'burnejo01',
#  'engliwo01',
#  'flaskro01',
#  'karowma01',
#  'kressre01',
#  'schubhe01',
#  'goldmjo01',
#  'hassljo01',
#  'jonesco02',
#  'moncefr01',
#  'montaed01',
#  'akersbi01',
#  'clarkst01',
#  'gardnra01',
#  'gelbech01',
#  'laryly01',
#  'marshdo02',
#  'mcnaier01',
#  'narlebi01',
#  'roetzed01',
#  'sankebe01',
#  'wuestya01',
#  'applilu01',
#  'leveyji01',
#  'mullegr01',
#  'ryanbl01',
#  'sladego01',
#  'smither01',
#  'warstra01',
#  'watsojo01',
#  'willihu01',
#  'adairji01',
#  'benesjo01',
#  'browelo01',
#  'jurgebi01',
#  'stevebo01',
#  'urbanbi01',
#  'wilsoch02',
#  'bluegot01',
#  'cihoced01',
#  'crosefr01',
#  'mclarar01',
#  'reissal01',
#  'vaughar01',
#  'webbsk01',
#  'haslimi01',
#  'knickbi01',
#  'travice01',
#  'chambjo01',
#  'kellere01',
#  'mcgeeda02',
#  'stranal01',
#  'bramhar01',
#  'chiozdi01',
#  'dedearo01',
#  'myersbi01',
#  'newsosk01',
#  'peersja01',
#  'culledi01',
#  'geragbe01',
#  'joosted01',
#  'milleed03',
#  'norrile01',
#  'parkesa01',
#  'amblewa01',
#  'brownli01',
#  'parkeac01',
#  'scharge01',
#  'schusbi01',
#  'trechfr01',
#  'youngde02',
#  'bartlir01',
#  'boudrlo01',
#  'feinbed01',
#  'gerlajo01',
#  'grysksi01',
#  'hitchji01',
#  'irwinto01',
#  'mattibo01',
#  'myersly01',
#  'rogerpa01',
#  'steinju01',
#  'walshjo04',
#  'brancal01',
#  'chapmfr02',
#  'croucfr01',
#  'lakeed01',
#  'lillabi01',
#  'neighbo01',
#  'quickha01',
#  'scalzsk01',
#  'wietewh01',
#  'bragabo01',
#  'filesa01',
#  'jumonge01',
#  'marioma01',
#  'monchal01',
#  'pofahji01',
#  'reesepe01',
#  'stewagl01',
#  'sturgbo01',
#  'torregi01',
#  'wallaja02',
#  'anderal01',
#  'frankmo01',
#  'merulle01',
#  'perrybo01',
#  'rizzuph01',
#  'stephve01',
#  'adkindi01',
#  'buricbi01',
#  'crossje01',
#  'eschela01',
#  'gearyhu01',
#  'liponjo01',
#  'peskyjo01',
#  'rojekst01',
#  'sullijo06',
#  'bartlbo01',
#  'brewsch01',
#  'busched01',
#  'delsaga01',
#  'hamrira01',
#  'hoovejo01',
#  'kerrbu01',
#  'ordento01',
#  'roberre01',
#  'barnhvi01',
#  'basined01',
#  'brownto02',
#  'floydbu01',
#  'hamnegr01',
#  'milosmi01',
#  'wilkibo01',
#  'yorkto02',
#  'zakfr01',
#  'buzasjo01',
#  'cihocal01',
#  'corbicl01',
#  'crawfgl01',
#  'flagewa01',
#  'kimbldi01',
#  'mottbi01',
#  'reynoda01',
#  'weingel01',
#  'whiteba01',
#  'caulfja01',
#  'darkal01',
#  'oneiljo02',
#  'pellaed01',
#  'priceja01',
#  'whitmfr01',
#  'albrija01',
#  'combsme01',
#  'cregebe01',
#  'curripe01',
#  'dentesa01',
#  'lapoira01',
#  'madrisa01',
#  'stallvi01',
#  'anderan01',
#  'berojo01',
#  'berryne01',
#  'clarkji02',
#  'demarbi01',
#  'fleitan01',
#  'meekssa01',
#  'smallro01',
#  'wilsogr01',
#  'davisto01',
#  'hancofr01',
#  'hemusso01',
#  'napleal01',
#  'ruferru01',
#  'carrach01',
#  'stricge01',
#  'uptonto01',
#  'brideji01',
#  'bridgro01',
#  'coledi01',
#  'cusicja01',
#  'demaejo01',
#  'jennibi01',
#  'loganjo01',
#  'mcmilro01',
#  'miranwi01',
#  'richtal01',
#  'thomabu02',
#  'verblge01',
#  'bollimi01',
#  'brinkle01',
#  'clarkbu01',
#  'groatdi01',
#  'hardibu01',
#  'klausbi01',
#  'koshocl01',
#  'kuennha01',
#  'littrja01',
#  'snydeje01',
#  'spencda01',
#  'consobi01',
#  'davalyo01',
#  'huntebi03',
#  'obrieed01',
#  'roigto01',
#  'schofdi01',
#  'verdifr01',
#  'wilhesp01',
#  'alliega01',
#  'bullage01',
#  'grammal01',
#  'heldwo01',
#  'kitsoch01',
#  'micelmi01',
#  'samforo01',
#  'carroto01',
#  'causewa01',
#  'georgal01',
#  'harrebi01',
#  'klinebo02',
#  'kuhnke01',
#  'peterbu01',
#  'schypje01',
#  'stephbo01',
#  'valdijo01',
#  'aparilu01',
#  'baxesmi01',
#  'bressed01',
#  'buddido01',
#  'fernach01',
#  'hicksbu01',
#  'luttrly01',
#  'durnbbo01',
#  'hamlike01',
#  'henribo01',
#  'kaskoed01',
#  'kennejo02',
#  'kubekto01',
#  'pritcbu01',
#  'rodgean01',
#  'alvaros01',
#  'amaroru01',
#  'brickfr02',
#  'hansero02',
#  'koppejo01',
#  'lillibo01',
#  'tatele01',
#  'vealco01',
#  'mahonji01',
#  'paganjo01',
#  'versazo01',
#  'willsma01',
#  'barondi01',
#  'cardele01',
#  'chacoel01',
#  'gotayju01',
#  'johnsbo02',
#  'winebo01',
#  'bowmaer01',
#  'brinked01',
#  'fregoji01',
#  'howsedi01',
#  'kubisja01',
#  'hartmjc01',
#  'linzph01',
#  'martima01',
#  'maxvida01',
#  'mcguimi01',
#  'menkede01',
#  'roberda02',
#  'samueam01',
#  'tracedi01',
#  'whiteel02',
#  'alleyge01',
#  'brownla01',
#  'jacksso01',
#  'martito01',
#  'moranal01',
#  'petrori01',
#  'vaughgl01',
#  'woodwwo01',
#  'campabe01',
#  'garrigi01',
#  'kessido01',
#  'lanieha01',
#  'shirlba01',
#  'belanma01',
#  'harrebu01',
#  'hernaja01',
#  'oylerra01',
#  'penaro01',
#  'eliale01',
#  'michage01',
#  'williji03',
#  'deanto01',
#  'gutiece01',
#  'heisebo01',
#  'huntzst01',
#  'lundgo01',
#  'matchto01',
#  'moralri01',
#  'alvarlu01',
#  'arciajo01',
#  'fernach02',
#  'floydbo01',
#  'mcfadle01',
#  'patekfr01',
#  'torrehe01',
#  'camillo01',
#  'chaneda01',
#  'davanje01',
#  'heideja01',
#  'librafr01',
#  'perezma01',
#  'roblera01',
#  'russebi01',
#  'stanlfr01',
#  'valenbo02',
#  'bakerfr03',
#  'bowala01',
#  'conceda01',
#  'crosbed01',
#  'duffyfr01',
#  'foliti01',
#  'kenneji01',
#  'martite01',
#  'metzgro01',
#  'ramirmi01',
#  'severri01',
#  'szotkke01',
#  'thompda01',
#  'anderdw01',
#  'auerbri01',
#  'bussera01',
#  'chrisbr01',
#  'fostele01',
#  'hackeri01',
#  'hernaen01',
#  'masonji01',
#  'meoliru01',
#  'richale01',
#  'speiech01',
#  'taverfr01',
#  'blankla01',
#  'gambljo01',
#  'guthbu01',
#  'hernaru02',
#  'kellemi02',
#  'robincr01',
#  'dentbu01',
#  'friaspe01',
#  'guerrma01',
#  'johnsti01',
#  'ostrobr01',
#  'phillmi01',
#  'terreje01',
#  'veryzto01',
#  'almonbi01',
#  'burleri01',
#  'dejesiv01',
#  'ferrese01',
#  'gomezlu01',
#  'lindja01',
#  'mendoma01',
#  'nordbti01',
#  'ramiror01',
#  'yountro01',
#  'belloro01',
#  'lemasjo01',
#  'mileymi01',
#  'reynocr01',
#  'sandtto01',
#  'scrivch01',
#  'smallro02',
#  'garciki01',
#  'griffal01',
#  'papeke01',
#  'rockepa01',
#  'templga01',
#  'wagnema01',
#  'berrada01',
#  'buskemi01',
#  'fischmi01',
#  'flannjo01',
#  'mcmilto02',
#  'picciro01',
#  'romered01',
#  'sextoji01',
#  'trammal01',
#  'washiro01',
#  'washiul01',
#  'anderji01',
#  'bakerch02',
#  'chappha01',
#  'cruzto02',
#  'normane01',
#  'ramosdo01',
#  'sherrde01',
#  'smithoz01',
#  'thondi01',
#  'aguaylu01',
#  'bonnebo01',
#  'conceon01',
#  'davisod01',
#  'dybzije01',
#  'faedole01',
#  'hoffmgl01',
#  'pettijo01',
#  'ramirma01',
#  'ramirra01',
#  'sulargu01',
#  'valdeju01',
#  'weissga01',
#  'fletcsc01',
#  'gardero01',
#  'mchenva01',
#  'penabe01',
#  'ripkeca01',
#  'roberan01',
#  'sernapa01',
#  'tollewa01',
#  'adamsri02',
#  'bellira01',
#  'biancbu01',
#  'dejohma01',
#  'francju01',
#  'juraked01',
#  'smithji02',
#  'zuvelpa01',
#  'anderda02',
#  'fernato01',
#  'foleyto02',
#  'gagnegr01',
#  'gutieja01',
#  'jeltzst01',
#  'jimenho01',
#  'meachbo01',
#  'owenda01',
#  'owensp01',
#  'salazan01',
#  'santara01',
#  'schofdi02',
#  'wilkecu01',
#  'wotusro01',
#  'bakerdo01',
#  'espinal01',
#  'jonesro01',
#  'kunkeje01',
#  'scranji01',
#  'smithke03',
#  'uribejo01',
#  'dunstsh01',
#  'gerbecr01',
#  'guilloz01',
#  'khalisa01',
#  'leema02',
#  'polidgu01',
#  'rileser01',
#  'runneto01',
#  'thomaan01',
#  'bellja01',
#  'diazed01',
#  'elsteke01',
#  'greenga01',
#  'larkiba01',
#  'quinore01',
#  'riverlu01',
#  'stillku01',
#  'sveumda01',
#  'blausje01',
#  'bookero01',
#  'brumlmi02',
#  'diazma01',
#  'dowelke01',
#  'fermife01',
#  'jackske01',
#  'pedrial01',
#  'weisswa01',
#  'escoban01',
#  'husonje01',
#  'jonesti02',
#  'perezto02',
#  'anderke01',
#  'benjami01',
#  'disarga01',
#  'richaje01',
#  'schaeje01',
#  'scottdi03',
#  'spierbi01',
#  'vizcajo01',
#  'vizquom01',
#  'yeldier01',
#  'baezke01',
#  'bordimi01',
#  'cedenan01',
#  'offerjo01',
#  'rosarvi01',
#  'santaan01',
#  'beltres01',
#  'benavfr01',
#  'claytro01',
#  'escobjo01',
#  'hernajo01',
#  'howarda02',
#  'magalev01',
#  'rodrica01',
#  'rossyri01',
#  'sanchre01',
#  'zoskyed01',
#  'alexama02',
#  'ariasal01',
#  'bournra01',
#  'coloncr01',
#  'figuebi01',
#  'guerrju01',
#  'listapa01',
#  'millejo05',
#  'valenjo02',
#  'valenjo03',
#  'abbotku01',
#  'bogarti01',
#  'correro01',
#  'crometr01',
#  'gilbe01',
#  'gomezch02',
#  'gutieri01',
#  'kessike01',
#  'lopezlu02',
#  'mearepa01',
#  'navarti01',
#  'shavejo01',
#  'stockke01',
#  'cruzfa01',
#  'gonzaal01',
#  'holbera01',
#  'milleor01',
#  'rodrial01',
#  'aurilri01',
#  'castrju01',
#  'jeterde01',
#  'ledesaa01',
#  'delgawi01',
#  'foxan01',
#  'garcino01',
#  'martipa03',
#  'ordonre01',
#  'perezne01',
#  'relafde01',
#  'renteed01',
#  'rodrito01',
#  'sheetan01',
#  'cabreor01',
#  'collilo01',
#  'cruzde01',
#  'friasha01',
#  'guevagi01',
#  'haltesh01',
#  'martife01',
#  'ordazlu01',
#  'polcoke01',
#  'tejadmi01',
#  'carusmi01',
#  'coraal01',
#  'gonzaal02',
#  'guillca01',
#  'lopezme01',
#  'martira03',
#  'nievejo01',
#  'dawkitr01',
#  'dellaja01',
#  'dranske01',
#  'garcije01',
#  'garcilu01',
#  'guzmacr01',
#  'lambda01',
#  'mcdonjo03',
#  'woodwch01',
#  'delarto01',
#  'furcara01',
#  'lugoju01',
#  'luuloke01',
#  'nichoke01',
#  'perezsa01',
#  'rolliji01',
#  'youngmi02',
#  'almoner01',
#  'berroan01',
#  'cintral01',
#  'eckstda01',
#  'everead01',
#  'izturce01',
#  'loftoja01',
#  'lopezfe01',
#  'mendedo01',
#  'ransoco01',
#  'uribeju01',
#  'vazqura01',
#  'wilsoja02',
#  'bloomwi01',
#  'escalfe01',
#  'moriami01',
#  'rogered01',
#  'santira01',
#  'scutama01',
#  'barmecl01',
#  'brunter01',
#  'crosbbo01',
#  'cruzen01',
#  'greenkh01',
#  'machaan01',
#  'morbajo01',
#  'olmedra01',
#  'peraljh01',
#  'reyesjo01',
#  'adamsru01',
#  'alfarja01',
#  'bartlja01',
#  'gilje01',
#  'harribr01',
#  'labanjo01',
#  'valdewi01',
#  'betanyu01',
#  'bynumfr01',
#  'cedenro02',
#  'giarrto01',
#  'hardyjj01',
#  'lopezpe01',
#  'quintom01',
#  'ramirha01',
#  'robleos01',
#  'rodrilu01',
#  'theriry01',
#  'wilsojo03',
#  'aybarer01',
#  'barnwch01',
#  'cannian01',
#  'dortame01',
#  'drewst01',
#  'faheybr01',
#  'navaros01',
#  'penato02',
#  'sanchan02',
#  'tulowtr01',
#  'cabreas01',
#  'escobyu01',
#  'hernalu01',
#  'huch01',
#  'ryanbr01',
#  'avilemi01',
#  'bernido01',
#  'bixlebr01',
#  'bococbr01',
#  'brignre01',
#  'escobal02',
#  'hollimi01',
#  'janispa01',
#  'johnsel02',
#  'kazmase01',
#  'lowrije01',
#  'maysoed01',
#  'ochoaiv01',
#  'pennicl01',
#  'ramiral03',
#  'torreei01',
#  'andruel01',
#  'cabreev01',
#  'desmoia01',
#  'dlugabr01',
#  'hernadi01',
#  'manzeto01',
#  'romerni01',
#  'castrst01',
#  'diazar01',
#  'donalja01',
#  'martios01',
#  'navarya01',
#  'rominan01',
#  'tejadru01',
#  'amarial01',
#  'cozarza01',
#  'crawfbr01',
#  'darnach01',
#  'escobed01',
#  'floripe01',
#  'iglesjo01',
#  'kozmape01',
#  'nishits01',
#  'parrian01',
#  'rodrijo05',
#  'selleju01',
#  'culbech01',
#  'diazju02',
#  'elmorja01',
#  'galvifr01',
#  'gonzama01',
#  'gregodi01',
#  'hechaad01',
#  'mercejo03',
#  'pastoty01',
#  'profaju01',
#  'rutlejo01',
#  'segurje01',
#  'simmoan01',
#  'triunca01',
#  'adriaeh01',
#  'beckhti01',
#  'bogaexa01',
#  'diazjo02',
#  'florewi01',
#  'millebr02',
#  'owingch01',
#  'semiema01',
#  'tovarwi01',
#  'villajo01',
#  'adamecr01',
#  'ahmedni01',
#  'annade01',
#  'arrueer01',
#  'omallsh01',
#  'polanjo01',
#  'rojasmi02',
#  'sardilu01',
#  'tayloch03',
#  'colemdu01',
#  'correca01',
#  'lindofr01',
#  'marteke01',
#  'perazjo01',
#  'russead02',
#  'seageco01',
#  'turnetr01',
#  'anderti01',
#  'arciaor01',
#  'diazal02',
#  'mondera02',
#  'motteta01',
#  'perezye01',
#  'rondojo02',
#  'storytr01',
#  'swansda01',
#  'crawfjp01',
#  'dejonpa01',
#  'lintz01',
#  'riddljt01',
#  'rosaram01',
#  'smithty01',
#  'urenari01',
#  'vinceza01',
#  'adamewi01',
#  'aveliab01',
#  'castrha01',
#  'guerrja02',
#  'gurrilo01',
#  'hampsga01',
#  'kingesc01',
#  'munozya01',
#  'newmake01',
#  'rodriro03',
#  'trahabl01']
